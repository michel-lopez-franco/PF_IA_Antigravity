# %% [markdown]
# # <Título del Módulo> — Práctica
#
# **Módulo**: `<ID>` | **Tipo**: PRÁCTICO | **Fecha**: YYYY-MM-DD

# %%
import sys
import time

import numpy as np

np.random.seed(42)
assert sys.version_info >= (3, 12), f"Python 3.12+ requerido, tienes {sys.version}"
_t0 = time.time()

# %%
from src.utils.dataset import generar_dataset

estados, observaciones = generar_dataset(escenario="S1", T=200, seed=42)
print(f"Dataset: estados {estados.shape}, observaciones {observaciones.shape}")

# %%
# [CELDA DE VALIDACIÓN — NO MODIFICAR]
# Referencia externa para comparación numérica
# rmse_ref se define aquí; el estudiante lo compara con su rmse_student

# Ejemplo (reemplazar con la referencia del módulo correspondiente):
# from filterpy.kalman import KalmanFilter
# ... setup ...
# rmse_ref = ...
rmse_ref: float = 0.0  # reemplazar con valor de referencia real

# %%
# TODO: implementar el filtro del módulo usando NumPy/SciPy únicamente
# from src.filtros.<modulo> import <NombreDelFiltro>
# ...
# rmse_student = ...

# %%
# Validación numérica automática
from src.utils.metricas import rmse as calcular_rmse

# Descomentar cuando rmse_student esté definido:
# TOL = 1e-4
# assert abs(rmse_student - rmse_ref) < TOL, \
#     f"RMSE {rmse_student:.6f} difiere de referencia {rmse_ref:.6f} — ver Errores comunes"
# assert np.all(np.isfinite(estado_estimado)), "NaN/inf detectado — ver Errores comunes"
print("Descomenta las aserciones tras implementar el filtro.")

# %% [markdown]
# ## Ejercicios guiados (base, ≤ 30 min)
#
# <Enunciado del ejercicio base con andamiaje completo.>

# %%
# Ejercicio guiado — completar las partes marcadas con TODO
# TODO: ...

# %% [markdown]
# ## Reto (opcional — sin andamiaje)
#
# <Enunciado del reto. El estudiante diseña su propia solución.>

# %%
# Smoke-test: verificar tiempo de ejecución total
_tiempo = time.time() - _t0
assert _tiempo < 60.0, f"Notebook tardó {_tiempo:.1f}s (máx 60s)"
print(f"Tiempo total de ejecución: {_tiempo:.2f}s ✓")

# %% [markdown]
# ## ¿Qué aprendiste?
#
# Aprendimos que…
#
# 1. <concepto práctico clave 1>
# 2. <concepto práctico clave 2>
# 3. <concepto práctico clave 3>
#
# ## ¿Qué sigue?
#
# El siguiente módulo es **<Nombre del módulo siguiente>**.
#
# Con el filtro que implementamos aquí, podremos <puente conceptual hacia el siguiente>.
