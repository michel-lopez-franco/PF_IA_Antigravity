# %% [markdown]
# # <Título del Módulo>
#
# **Módulo**: `<ID>` | **Tipo**: TEÓRICO | **Fecha**: YYYY-MM-DD
#
# > **Prerequisitos**: <lista de conceptos necesarios>

# %% [markdown]
# ## Objetivos de aprendizaje
#
# Al completar este módulo, el estudiante podrá:
#
# 1. <Verbo de acción medible + concepto>
# 2. <Verbo de acción medible + concepto>
# 3. <Verbo de acción medible + concepto>

# %%
import sys

import numpy as np

np.random.seed(42)
assert sys.version_info >= (3, 12), f"Python 3.12+ requerido, tienes {sys.version}"

# %% [markdown]
# ## Intuición
#
# <Explicación informal del concepto central — sin fórmulas todavía.
# Usa analogías, ejemplos de la vida cotidiana, o motivación del problema.>

# %% [markdown]
# ## Derivación formal
#
# <Desarrollo matemático paso a paso. Cada paso debe seguir del anterior sin saltos.
# Si se omite un paso, citar la referencia o incluir un apéndice.>
#
# $$
# \text{<fórmula central del módulo>}
# $$

# %%
# Verificación numérica de la derivación
# Reproducir el resultado analítico con NumPy

# %% [markdown]
# ## Ejemplo numérico paso a paso
#
# <Trabajar un ejemplo concreto con números específicos.
# Mostrar cada paso intermedio explícitamente.>

# %%
# Código del ejemplo numérico
# Valores concretos — sin variables abstractas

# %% [markdown]
# ## Ejercicios guiados
#
# ### Ejercicio base (≤ 30 min)
#
# <Enunciado con andamiaje completo.>

# %%
# TODO: completar el ejercicio base

# %% [markdown]
# ### Reto (opcional — sin andamiaje)
#
# <Enunciado del reto de mayor complejidad.>

# %% [markdown]
# ## Evaluación
#
# <Lista de problemas con criterios de éxito medibles.
# Cada problema debe tener una salida esperada numérica o un assert verificable.>

# %% [markdown]
# ## Errores comunes
#
# ### Error 1: <nombre del error>
#
# **Síntoma**: <qué observa el estudiante>
#
# **Diagnóstico**: <cómo identificar la causa>
#
# **Solución**: <corrección correcta>
#
# ---
#
# ### Error 2: <nombre del error>
#
# **Síntoma**: <qué observa el estudiante>
#
# **Diagnóstico**: <cómo identificar la causa>
#
# **Solución**: <corrección correcta>

# %% [markdown]
# ## ¿Qué aprendiste?
#
# Aprendimos que…
#
# 1. <concepto clave 1>
# 2. <concepto clave 2>
# 3. <concepto clave 3>
# 4. <concepto clave 4>
# 5. <concepto clave 5>

# %% [markdown]
# ## ¿Qué sigue?
#
# El siguiente módulo es **<Nombre del módulo siguiente>**.
#
# Lo que aprendimos aquí nos permite <describir el puente conceptual concreto>.
